# %%
import pandas as pd
from sklearn.tree import DecisionTreeRegressor

# %%
# Reading the Dataset
dataset = pd.read_csv('insurance_pre.csv')

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset=pd.get_dummies(dataset,drop_first=True)

# %%
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400     False        True
# 1      18  33.770         1   1725.55230      True       False
# 2      28  33.000         3   4449.46200      True       False
# 3      33  22.705         0  21984.47061      True       False
# 4      32  28.880         0   3866.85520      True       False
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830      True       False
# 1334   18  31.920         0   2205.98080     False       False
# 1335   18  36.850         0   1629.83350     False       False
# 1336   21  25.800         0   2007.94500     False       False
# 1337   61  29.070         0  29141.36030     False        True
#
# [1338 rows x 6 columns]

# %%
indep=dataset[['age', 'bmi', 'children','sex_male', 'smoker_yes']]
dep=dataset['charges']

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
indep=sc.fit_transform(indep)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeRegressor
param_grid = {'criterion':['squared_error', 'friedman_mse', 'absolute_error', 'poisson'],
'max_features': [['sqrt', 'log2'], default := None],
'splitter':['best','random']}

grid = GridSearchCV(DecisionTreeRegressor(), param_grid, refit = True, verbose=3, n_jobs=-1)
# fitting the model for grid search
grid.fit(indep, dep)
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# C:\Users\rohit\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:378: FitFailedWarning:
# 40 fits failed out of a total of 80.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 19 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\rohit\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\rohit\anaconda3\Lib\site-packages\sklearn\tree\_classes.py", line 1247, in fit
#     super().fit(
#   File "C:\Users\rohit\anaconda3\Lib\site-packages\sklearn\tree\_classes.py", line 177, in fit
#     self._validate_params()
#   File "C:\Users\rohit\anaconda3\Lib\site-packages\sklearn\base.py", line 600, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\rohit\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 97, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of DecisionTreeRegressor must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'log2', 'sqrt', 'auto' (deprecated)} or None. Got ['sqrt', 'log2'] instead.
#
# --------------------------------------------------------------------------------
# 8 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\rohit\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\rohit\anaconda3\Lib\site-packages\sklearn\tree\_classes.py", line 1247, in fit
#     super().fit(
#   File "C:\Users\rohit\anaconda3\Lib\site-packages\sklearn\tree\_classes.py", line 177, in fit
#     self._validate_params()
#   File "C:\Users\rohit\anaconda3\Lib\site-packages\sklearn\base.py", line 600, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\rohit\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 97, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of DecisionTreeRegressor must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'log2', 'auto' (deprecated), 'sqrt'} or None. Got ['sqrt', 'log2'] instead.
#
# --------------------------------------------------------------------------------
# 9 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\rohit\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\rohit\anaconda3\Lib\site-packages\sklearn\tree\_classes.py", line 1247, in fit
#     super().fit(
#   File "C:\Users\rohit\anaconda3\Lib\site-packages\sklearn\tree\_classes.py", line 177, in fit
#     self._validate_params()
#   File "C:\Users\rohit\anaconda3\Lib\site-packages\sklearn\base.py", line 600, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\rohit\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 97, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of DecisionTreeRegressor must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'auto' (deprecated), 'log2', 'sqrt'} or None. Got ['sqrt', 'log2'] instead.
#
# --------------------------------------------------------------------------------
# 3 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\rohit\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\rohit\anaconda3\Lib\site-packages\sklearn\tree\_classes.py", line 1247, in fit
#     super().fit(
#   File "C:\Users\rohit\anaconda3\Lib\site-packages\sklearn\tree\_classes.py", line 177, in fit
#     self._validate_params()
#   File "C:\Users\rohit\anaconda3\Lib\site-packages\sklearn\base.py", line 600, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\rohit\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 97, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of DecisionTreeRegressor must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'auto' (deprecated), 'sqrt', 'log2'} or None. Got ['sqrt', 'log2'] instead.
#
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\rohit\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\rohit\anaconda3\Lib\site-packages\sklearn\tree\_classes.py", line 1247, in fit
#     super().fit(
#   File "C:\Users\rohit\anaconda3\Lib\site-packages\sklearn\tree\_classes.py", line 177, in fit
#     self._validate_params()
#   File "C:\Users\rohit\anaconda3\Lib\site-packages\sklearn\base.py", line 600, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\rohit\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 97, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of DecisionTreeRegressor must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'sqrt', 'auto' (deprecated), 'log2'} or None. Got ['sqrt', 'log2'] instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\rohit\anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:952: UserWarning: One or more of the test scores are non-finite: [       nan        nan 0.70257116 0.69414185        nan        nan
#  0.70083453 0.69429915        nan        nan 0.71907152 0.70922937
#         nan        nan 0.72073221 0.66927104]
#   warnings.warn(
# GridSearchCV(estimator=DecisionTreeRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'friedman_mse',
#                                        'absolute_error', 'poisson'],
#                          'max_features': [['sqrt', 'log2'], None],
#                          'splitter': ['best', 'random']},
#              verbose=3)

# %%
# print best parameter after tuning
#print(grid.best_params_)
re=grid.cv_results_
#print(re)
grid_predictions = grid.predict(indep)

# %%
from sklearn.metrics import r2_score
# Calculate R^2 score
r_score = r2_score(dep, grid_predictions)
print("The R_score value for best parameter {}:".format(grid.best_params_), r_score)
# Out:
# The R_score value for best parameter {'criterion': 'poisson', 'max_features': None, 'splitter': 'best'}: 0.998667156135576

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.000000  0.000000e+00         0.000000        0.000000
# 1        0.000000  0.000000e+00         0.000000        0.000000
# 2        0.009373  7.652903e-03         0.000000        0.000000
# 3        0.003125  6.249142e-03         0.000000        0.000000
# 4        0.000000  0.000000e+00         0.000000        0.000000
# 5        0.000000  0.000000e+00         0.000000        0.000000
# 6        0.006249  7.653371e-03         0.000000        0.000000
# 7        0.009373  7.652670e-03         0.000000        0.000000
# 8        0.000000  0.000000e+00         0.000000        0.000000
# 9        0.000000  0.000000e+00         0.000000        0.000000
# 10       0.031243  1.168008e-07         0.000000        0.000000
# 11       0.021870  7.652728e-03         0.003125        0.006249
# 12       0.000000  0.000000e+00         0.000000        0.000000
# 13       0.000000  0.000000e+00         0.000000        0.000000
# 14       0.003124  6.247902e-03         0.003124        0.006248
# 15       0.000000  0.000000e+00         0.000000        0.000000
#
#    param_criterion param_max_features param_splitter  \
# 0    squared_error       [sqrt, log2]           best
# 1    squared_error       [sqrt, log2]         random
# 2    squared_error               None           best
# 3    squared_error               None         random
# 4     friedman_mse       [sqrt, log2]           best
# 5     friedman_mse       [sqrt, log2]         random
# 6     friedman_mse               None           best
# 7     friedman_mse               None         random
# 8   absolute_error       [sqrt, log2]           best
# 9   absolute_error       [sqrt, log2]         random
# 10  absolute_error               None           best
# 11  absolute_error               None         random
# 12         poisson       [sqrt, log2]           best
# 13         poisson       [sqrt, log2]         random
# 14         poisson               None           best
# 15         poisson               None         random
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...                NaN
# 1   {'criterion': 'squared_error', 'max_features':...                NaN
# 2   {'criterion': 'squared_error', 'max_features':...           0.733383
# 3   {'criterion': 'squared_error', 'max_features':...           0.736336
# 4   {'criterion': 'friedman_mse', 'max_features': ...                NaN
# 5   {'criterion': 'friedman_mse', 'max_features': ...                NaN
# 6   {'criterion': 'friedman_mse', 'max_features': ...           0.731071
# 7   {'criterion': 'friedman_mse', 'max_features': ...           0.692961
# 8   {'criterion': 'absolute_error', 'max_features'...                NaN
# 9   {'criterion': 'absolute_error', 'max_features'...                NaN
# 10  {'criterion': 'absolute_error', 'max_features'...           0.750633
# 11  {'criterion': 'absolute_error', 'max_features'...           0.718383
# 12  {'criterion': 'poisson', 'max_features': ['sqr...                NaN
# 13  {'criterion': 'poisson', 'max_features': ['sqr...                NaN
# 14  {'criterion': 'poisson', 'max_features': None,...           0.743417
# 15  {'criterion': 'poisson', 'max_features': None,...           0.695463
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0                 NaN                NaN                NaN
# 1                 NaN                NaN                NaN
# 2            0.652527           0.725581           0.704708
# 3            0.611726           0.697422           0.679783
# 4                 NaN                NaN                NaN
# 5                 NaN                NaN                NaN
# 6            0.655794           0.722991           0.708841
# 7            0.577568           0.732914           0.759940
# 8                 NaN                NaN                NaN
# 9                 NaN                NaN                NaN
# 10           0.618920           0.740421           0.733520
# 11           0.639254           0.738073           0.741938
# 12                NaN                NaN                NaN
# 13                NaN                NaN                NaN
# 14           0.657509           0.762025           0.720903
# 15           0.598119           0.660253           0.723245
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0                 NaN              NaN             NaN                9
# 1                 NaN              NaN             NaN                9
# 2            0.696656         0.702571        0.028365                4
# 3            0.745443         0.694142        0.047794                7
# 4                 NaN              NaN             NaN                9
# 5                 NaN              NaN             NaN                9
# 6            0.685475         0.700835        0.027327                5
# 7            0.708113         0.694299        0.062640                6
# 8                 NaN              NaN             NaN                9
# 9                 NaN              NaN             NaN                9
# 10           0.751864         0.719072        0.050530                2
# 11           0.708499         0.709229        0.037102                3
# 12                NaN              NaN             NaN                9
# 13                NaN              NaN             NaN                9
# 14           0.719807         0.720732        0.035264                1
# 15           0.669276         0.669271        0.041817                8

# %%
regressor = DecisionTreeRegressor()

# %%
# Fit the model
regressor.fit(indep, dep)
dep=regressor.predict(indep)

# %%
import pickle

# %%
filename="mullinegrid_final.sav"
pickle.dump(regressor,open(filename,"wb"))

# %%
model=pickle.load(open(filename,"rb"))

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
indep=sc.fit_transform(indep)

# %%
age_input=float(input("Age:"))
bmi_input=float(input("BMI:"))
children_input=float(input("Children:"))
sex_male_input=int(input("Sex Male 0 or 1:"))
smoker_yes_input=int(input("Smoker Yes 0 or 1:"))
# Out:
# Age: 23
# BMI: 33
# Children: 2
# Sex Male 0 or 1: 0
# Smoker Yes 0 or 1: 1

# %%
preinput=sc.transform([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])
print(preinput)
# Out:
# [[2.30000000e+01 3.30000000e+01 2.00000000e+00 1.23468749e-16
#   1.00000000e+00]]

# %%
Future_Prediction=grid.predict(preinput)

#change the paramter,play with it.
print("Future_Prediction={}".format(Future_Prediction))
# Out:
# Future_Prediction=[63770.42801]
